# %%
320/192
# Out:
# 1.6666666666666667

# %%
192/128
# Out:
# 1.5

# %%
1000/1.5
# Out:
# 666.6666666666666

# %%
64*16
# Out:
# 1024

# %%
(960/1.5)/64
# Out:
# 10.0

# %%
640

# %%
for i in range(16):
    print(i*64)
# Out:
# 0
# 64
# 128
# 192
# 256
# 320
# 384
# 448
# 512
# 576
# 640
# 704
# 768
# 832
# 896
# 960
